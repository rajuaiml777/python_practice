# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.w3schools.com/'  # Replace with the URL of the website
response = requests.get(url)

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.w3schools.com/'  # Replace with the URL of the website

# Make an HTTP GET request to the web page
response = requests.get(url)

# Create a BeautifulSoup object
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <title>W3Schools Online Web Tutorials</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="HTML, Python, CSS, SQL, JavaScript, How to, PHP, Java, C, C++, C#, jQuery, Bootstrap, Colors, W3.CSS, XML, MySQL, Icons, NodeJS, React, Graphics, Angular, R, AI, Git, Data Science, Code Game, Tutorials, Programming, Web Development, Training, Learning, Quiz, Exercises, Courses, Lessons, References, Examples, Learn to code, Source code, Demos, Tips, Website" name="Keywords"/>
# <meta content="Well organized and easy to understand Web building tutorials with lots of examples of how to use HTML, CSS, JavaScript, SQL, Python, PHP, Bootstrap, Java, XML and more." name="Description"/>
# <meta content="https://www.w3schools.com/images/w3schools_logo_436_2.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# ...

# %%
# Find security-related elements using CSS selectors
security_elements = soup.select('.security-class')  # Replace '.security-class' with the appropriate selector
security_elements
# Out:
# []

# %%
for element in security_elements:
    # Extract security details from each element
    title = element.select_one('.title-class').text.strip()  # Replace '.title-class' with the appropriate selector
    
    print()
    description = element.select_one('.description-class').text.strip()  # Replace '.description-class' with the appropriate selector

    # Print or process the security details
    print("Title:", title)
    print("Description:", description)
    print("")

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <title>W3Schools Online Web Tutorials</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="HTML, Python, CSS, SQL, JavaScript, How to, PHP, Java, C, C++, C#, jQuery, Bootstrap, Colors, W3.CSS, XML, MySQL, Icons, NodeJS, React, Graphics, Angular, R, AI, Git, Data Science, Code Game, Tutorials, Programming, Web Development, Training, Learning, Quiz, Exercises, Courses, Lessons, References, Examples, Learn to code, Source code, Demos, Tips, Website" name="Keywords"/>
# <meta content="Well organized and easy to understand Web building tutorials with lots of examples of how to use HTML, CSS, JavaScript, SQL, Python, PHP, Bootstrap, Java, XML and more." name="Description"/>
# <meta content="https://www.w3schools.com/images/w3schools_logo_436_2.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# ...

# %%
# Example: Extracting security advisories
advisories = soup.find_all('div', class_='security-advisory')
for advisory in advisories:
    title = advisory.find('h2').text.strip()
    date = advisory.find('span', class_='date').text.strip()
    description = advisory.find('p').text.strip()
    print(f'Title: {title}\nDate: {date}\nDescription: {description}\n')

# %%
import requests
import ssl

# Disable SSL certificate verification
ssl._create_default_https_context = ssl._create_unverified_context

def check_page_security(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            print("Page is valid and accessible.")

            # Check SSL certificate validity
            cert = response.connection.sock.getpeercert()
            cert_info = ssl.cert_time_to_seconds(cert['notAfter'])
            current_time = ssl.cert_time_to_seconds(ssl._ssl._test_decode_time())
            if current_time < cert_info:
                print("SSL certificate is valid.")
            else:
                print("SSL certificate has expired.")
        else:
            print(f"Page is invalid. Status code: {response.status_code}")
    except requests.exceptions.RequestException as e:
        print(f"Error occurred while accessing the page: {e}")

# Example usage
url = 'https://www.w3schools.com/'  # Replace with the URL of the web page you want to check
check_page_security(url)
# Out:
# Page is valid and accessible.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21972\2670686424.py in <module>
#      26 # Example usage
#      27 url = 'https://www.w3schools.com/'  # Replace with the URL of the web page you want to check
# ---> 28 check_page_security(url)
#
# ~\AppData\Local\Temp\ipykernel_21972\2670686424.py in check_page_security(url)
#      12
#      13             # Check SSL certificate validity
# ---> 14             cert = response.connection.sock.getpeercert()
#      15             cert_info = ssl.cert_time_to_seconds(cert['notAfter'])
#      16             current_time = ssl.cert_time_to_seconds(ssl._ssl._test_decode_time())
#
# AttributeError: 'HTTPAdapter' object has no attribute 'sock'

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.w3schools.com/'  # Replace with the URL of the web page you want to inspect

# Make an HTTP GET request to the web page
response = requests.get(url)

# Create a BeautifulSoup object
soup = BeautifulSoup(response.content, 'html.parser')

# Find and print specific elements using CSS selectors
title_element = soup.select_one('h1')  # Find the first <h1> element
if title_element:
    print("Title:", title_element.text.strip())

links = soup.select('a')  # Find all <a> elements
for link in links:
    print("Link:", link['href'])
# Out:
# Title: Learn to Code
# Link: https://www.w3schools.com
# Link: javascript:void(0)
# Link: javascript:void(0)
# Link: javascript:void(0)
# Link: javascript:void(0)
# Link: javascript:void(0)
# Link: https://profile.w3schools.com/log-in?redirect_url=https%3A%2F%2Fmy-learning.w3schools.com
# Link: https://billing.w3schools.com/products/spaces?frequency=monthly&changePlan=true
# Link: /signup/index.php
# Link: /spaces/index.php
# Link: /bootcamp/index.php
# Link: javascript:void(0)
# Link: javascript:void(0);
# Link: javascript:void(0);
# Link: javascript:void(0);
# Link: javascript:void(0);
# Link: /spaces/index.php
# Link: /signup/index.php
# Link: /bootcamp/index.php
# Link: /videos/index.php
# Link: https://shop.w3schools.com
# Link: https://www.facebook.com/w3schoolscom/
# Link: https://www.instagram.com/w3schools.com_official/
# Link: https://www.linkedin.com/company/w3schools.com/
# Link: https://discord.gg/6Z7UaRbUQM
# Link: /html/default.asp
# Link: /html/default.asp
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.w3schools.com/'  # Replace with the desired URL

# Send an HTTP GET request
response = requests.get(url)

# Parse the HTML content
soup = BeautifulSoup(response.text, "html.parser")

# Extract the security information
security_info = soup.find("meta", attrs={"name": "security"}).get("content")

print("Security Information:", security_info)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21972\360646296.py in <module>
#      11
#      12 # Extract the security information
# ---> 13 security_info = soup.find("meta", attrs={"name": "security"}).get("content")
#      14
#      15 print("Security Information:", security_info)
#
# AttributeError: 'NoneType' object has no attribute 'get'

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.geeksforgeeks.org/'  # Replace with the desired URL

# Send an HTTP GET request
response = requests.get(url)

# Parse the HTML content
soup = BeautifulSoup(response.text, "html.parser")

# Extract the security information if it exists
meta_tag = soup.find("meta", attrs={"name": "security"})
meta_tag

# %%
if meta_tag:
    security_info = meta_tag.get("content")
    print("Security Information:", security_info)
else:
    print("No security information found.")
# Out:
# No security information found.
